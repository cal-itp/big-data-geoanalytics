# %% [markdown]
# # Geotab API
#
# * testing the geotab API
# * goal is to replicate workflow for CT users
#     * Would like to be able to get the vehicle counts for medium and heavy trucks

# %%
import pandas as pd
from siuba import *

# %%
# ! pip install mygeotab

# %%
import mygeotab

# %%
import config

# %%
api = mygeotab.API(username='natalie.amberg@dot.ca.gov', password= config.password, database='california_state')
api.authenticate()

api.get('Device', resultsLimit=1)
# Out:
# ---------------------------------------------------------------------------
# MyGeotabException                         Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/mygeotab/api.py:259, in API.authenticate(self)
#     254 auth_data = dict(
#     255     database=self.credentials.database,
#     256     userName=self.credentials.username,
#     257     password=self.credentials.password,
#     258 )
# --> 259 result = _query(
#     260     self._server,
#     261     "Authenticate",
#     262     auth_data,
#     263     self.timeout,
#     264     verify_ssl=self._is_verify_ssl,
#     265     proxies=self._proxies,
#     266     cert=self._cert,
#     267 )
#     268 if result:
#
# File /opt/conda/lib/python3.11/site-packages/mygeotab/api.py:410, in _query(server, method, parameters, timeout, verify_ssl, proxies, cert)
#     409     return response.text
# --> 410 return _process(json_deserialize(response.text))
#
# ...
