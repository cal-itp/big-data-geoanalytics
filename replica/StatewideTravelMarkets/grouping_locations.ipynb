# %% [markdown]
# # Grouping Locations for Origins and Destinations

# %%
import gcsfs as fs
import geopandas as gpd
import numpy as np
import pandas as pd
from calitp_data_analysis import get_fs, utils
from calitp_data_analysis.sql import to_snakecase
from siuba import *

fs = get_fs()

# %%
import altair as alt
import folium
from IPython.display import HTML
from calitp_data_analysis import calitp_color_palette as cp

# %%
import _location_utils

# %%
gcs_path = "gs://calitp-analytics-data/data-analyses/big_data/STM/origins/"

# %%
with get_fs().open(f"{gcs_path}replica-stm_origin_la-03_18_26-destination_layer.zip") as f:
        dest = to_snakecase(gpd.read_file(f))

# %%
# with get_fs().open(f"{gcs_path}replica-stm_pois-02_05_26-origin_layer.zip") as f:
#         origins = to_snakecase(gpd.read_file(f))

# %%
dest.sample()
# Out:
#               geoname           customgeo  centrlat  centrlon    sqmi  destin  \
# 3078  872832b15ffffff  608693120724369400   38.5584 -121.4715  2.0684       5
#
#       dest_sqmi                                           geometry
# 3078     2.4173  POLYGON ((-121.46267 38.54782, -121.47922 38.5...

# %%
# top20_dest = (dest.sort_values(by='tripsbydestination', ascending=False)).head(20)

# %%
# top20_dest
# Out:
#                       geoname  customgeoid  centroidlat  centroidlon  \
# 0              67 (Clark, NV)  32003006700      36.1138    -115.1704
# 1   9800.28 (Los Angeles, CA)   6037980028      33.9398    -118.4135
# 2              68 (Clark, NV)  32003006800      36.0850    -115.1539
# 3       85.11 (San Diego, CA)   6073008511      32.8260    -117.1416
# 4         626.10 (Orange, CA)   6059062610      33.6692    -117.8604
# 5         755.16 (Orange, CA)   6059075516      33.6930    -117.8450
# 6   9800.35 (Los Angeles, CA)   6037980035      34.0124    -117.9434
# 7       4415.03 (Alameda, CA)   6001441503      37.5048    -122.0331
# 8   5050.06 (Santa Clara, CA)   6085505006      37.3936    -121.9211
# 9     78 (San Bernardino, CA)   6071007800      34.0734    -117.2192
# 10  5052.02 (Santa Clara, CA)   6085505202      37.3703    -121.9607
# 11      93.07 (San Diego, CA)   6073009307      32.7744    -117.1351
# 12       9843 (San Mateo, CA)   6081984300      37.6208    -122.3785
# ...

# %%
# (dest.head(20)).explore()

# %%
# top20_dest['dest_name_long'] = top20_dest['geoname'].str.split('(').str[1]
# top20_dest['dest_code'] = top20_dest['geoname'].str.split('(').str[0]

# %%
# top20_dest['dest_name_long'] = top20_dest['dest_name_long'].str.replace(')', '')
# Out:
# /tmp/ipykernel_931/3533316647.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   top20_dest['dest_name_long'] = top20_dest['dest_name_long'].str.replace(')', '')

# %%
# top20_dest['dest_name_short'] = top20_dest['dest_name_long'].str.split(',').str[0]

# %%
# top20_dest['dest_name'] = top20_dest["dest_name_short"] + "_" + top20_dest['dest_code']

# %%
# top20_dest['dest_name'] = top20_dest['dest_name'].str.replace(' ', '')

# %%
# dest_list = top20_dest['dest_name'].to_list()

# %%
### hashing out after running 
### we dont need this for the analysis since we are looking at all trips
# _location_utils.aggregate_destination_station_geometries(top20_dest, dest_list, "dest_name")

# %%
origin_la_980028 = to_snakecase(pd.read_csv(f"{gcs_path}origins/replica-stm_origin_la_980028-02_06_26-trips_dataset.csv"))
# Out:
# /tmp/ipykernel_931/334489282.py:1: DtypeWarning: Columns (18,19,20,25,26,28,29,30,31,33,36,38,39,40,41,42,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   origin_la_980028 = to_snakecase(pd.read_csv(f"{gcs_path}origins/replica-stm_origin_la_980028-02_06_26-trips_dataset.csv"))

# %%
origin_la_980028.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260992 entries, 0 to 260991
# Data columns (total 52 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   activity_id                        260992 non-null  uint64
#  1   origin_bgrp_2020                   260992 non-null  object
#  2   origin_trct_2020                   260992 non-null  object
#  3   origin_cty_2020                    260992 non-null  object
#  4   origin_st_2020                     260992 non-null  object
#  5   destination_bgrp_2020              260992 non-null  object
#  6   destination_trct_2020              260992 non-null  object
#  7   destination_cty_2020               260992 non-null  object
#  8   destination_st_2020                260992 non-null  object
#  9   primary_mode                       260992 non-null  object
#  10  trip_purpose                       260992 non-null  object
# ...
