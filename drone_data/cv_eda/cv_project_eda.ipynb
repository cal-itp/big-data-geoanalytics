# %% [markdown]
# # Drone cv eda
# early stages

# %% [markdown]
# ## Requirements
# * Drone capable of capturing high-resolution video from a stable overhead perspective.
#     * Derek Kantar with Maintenance has access to drones, he has offered us access
#     * next steps - speak with the Maintenance drone folks, better understand the data outputs we can access.
# * Python environment with computer vision libraries.
#     * Do we have access to the tools we need now?

# %% [markdown]
# ## Tools and Libraries in Python
# **OpenCV** – for basic video/image processing.
#
# **YOLOv5 or YOLOv8 (You Only Look Once)** – for real-time object detection (cars, bikes, people, etc.).
#
# **DeepSORT or ByteTrack** – for multi-object tracking across frames (important for counts and patterns).
#
# **Pandas/Numpy** – for storing and analyzing results.
#
# **Matplotlib or Seaborn** – for visualization.

# %% [markdown]
# ## What We Can Detect
# * Vehicles (cars, trucks, buses) – detect and count by frame or time interval.
# * Bicycles – distinguish from motorcycles using better-trained models.
# * Pedestrians – track movement across sidewalks, crossings, etc.
# * Turning Movements – track trajectories to derive turning behavior.
# * Traffic Patterns – infer flow rates, queue lengths, speed estimates, etc.

# %% [markdown]
# ## General Workflow
# * Collect video footage with the drone, ideally overhead and fixed.
# * Preprocess the footage (resize, stabilize, convert to frames).
# * Use an object detection model (like YOLO) to identify objects in each frame.
# * Apply tracking to follow individuals/vehicles across frames.
# * Aggregate counts and movement paths.
# * Analyze patterns: speed, lane use, crossings, etc.

# %% [markdown]
# ## Challenges
# * Camera angle and altitude affect accuracy.
# * Lighting and weather can degrade model performance.
# * Occlusions (e.g., objects blocking others).
# * Privacy concerns – especially with pedestrian detection.

# %% [markdown]
# ## Open Datasets and Pretrained Models
# * Pretrained YOLO models can detect car, bus, truck, bicycle, person out of the box.
# * Models can be fine-tune using datasets like:
#     * Cityscapes
#     * MOTChallenge (Multi-Object Tracking)
#     * COCO dataset

# %% [markdown]
# ## Bonus: Example Projects and Frameworks
# * Roboflow – for managing and training custom models (great for beginners).
# * OpenDataCam – open-source tool using YOLO for traffic counting.
# * CVAT – for annotating drone footage to train custom models.

# %% [markdown]
# ## Example Use Case:
# * If you have a 2-minute drone video over a 4-way intersection:
# * YOLOv8 detects objects frame-by-frame.
# * DeepSORT tracks each vehicle and person uniquely.
# * Python counts total cars, turning movements, and pedestrian crossing frequency.
# * Heatmaps or flow diagrams show patterns over time.

# %% [markdown]
# ## Example Script

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install opencv-python matplotlib
# !pip install yolov5  # Installs Ultralytics YOLOv5 wrapper
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (27 kB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from torchvision) (1.24.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.7.0%2Bcpu-cp311-cp311-manylinux_2_28_x86_64.whl (176.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 MB 71.2 MB/s eta 0:00:0000:0100:01
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.22.0%2Bcpu-cp311-cp311-manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 34.3 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.7.0%2Bcpu-cp311-cp311-manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.6 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.7.0+cpu torchaudio-2.7.0+cpu torchvision-0.22.0+cpu
# Collecting opencv-python
#   Using cached opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.5.0)
# Requirement already satisfied: numpy>=1.21.2 in /opt/conda/lib/python3.11/site-packages (from opencv-python) (1.24.4)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 89.3 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# Collecting yolov5
#   Downloading yolov5-7.0.14-py37.py38.py39.py310-none-any.whl.metadata (10 kB)
# Requirement already satisfied: gitpython>=3.1.30 in /opt/conda/lib/python3.11/site-packages (from yolov5) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /opt/conda/lib/python3.11/site-packages (from yolov5) (3.5.0)
# Requirement already satisfied: numpy>=1.18.5 in /opt/conda/lib/python3.11/site-packages (from yolov5) (1.24.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /opt/conda/lib/python3.11/site-packages (from yolov5) (4.11.0.86)
# Requirement already satisfied: Pillow>=7.1.2 in /opt/conda/lib/python3.11/site-packages (from yolov5) (11.1.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from yolov5) (5.9.8)
# Requirement already satisfied: PyYAML>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from yolov5) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.11/site-packages (from yolov5) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from yolov5) (1.11.4)
# Collecting thop>=0.1.1 (from yolov5)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: torch>=1.7.0 in /opt/conda/lib/python3.11/site-packages (from yolov5) (2.7.0+cpu)
# Requirement already satisfied: torchvision>=0.8.1 in /opt/conda/lib/python3.11/site-packages (from yolov5) (0.22.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.11/site-packages (from yolov5) (4.67.1)
# Collecting ultralytics>=8.0.100 (from yolov5)
#   Downloading ultralytics-8.3.140-py3-none-any.whl.metadata (37 kB)
# Collecting tensorboard>=2.4.1 (from yolov5)
#   Downloading tensorboard-2.19.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.11/site-packages (from yolov5) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.11/site-packages (from yolov5) (0.11.2)
# Requirement already satisfied: setuptools>=65.5.1 in /opt/conda/lib/python3.11/site-packages (from yolov5) (68.2.2)
# Collecting fire (from yolov5)
#   Downloading fire-0.7.0.tar.gz (87 kB)
#   Preparing metadata (setup.py) ... done
# Collecting boto3>=1.19.1 (from yolov5)
#   Downloading boto3-1.38.19-py3-none-any.whl.metadata (6.6 kB)
# Collecting sahi>=0.11.10 (from yolov5)
#   Downloading sahi-0.11.23-py3-none-any.whl.metadata (17 kB)
# Collecting huggingface-hub<0.25.0,>=0.12.0 (from yolov5)
#   Downloading huggingface_hub-0.24.7-py3-none-any.whl.metadata (13 kB)
# Collecting roboflow>=0.2.29 (from yolov5)
#   Downloading roboflow-1.1.64-py3-none-any.whl.metadata (9.7 kB)
# Collecting botocore<1.39.0,>=1.38.19 (from boto3>=1.19.1->yolov5)
#   Downloading botocore-1.38.19-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from boto3>=1.19.1->yolov5) (1.0.1)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3>=1.19.1->yolov5)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython>=3.1.30->yolov5) (4.0.11)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (2023.12.2)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<0.25.0,>=0.12.0->yolov5) (4.12.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3->yolov5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3->yolov5) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3->yolov5) (1.4.8)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3->yolov5) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib>=3.3->yolov5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.1.4->yolov5) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->yolov5) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->yolov5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->yolov5) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->yolov5) (2024.12.14)
# Collecting idna<4,>=2.5 (from requests>=2.23.0->yolov5)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow>=0.2.29->yolov5)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pillow-heif>=0.18.0 (from roboflow>=0.2.29->yolov5)
#   Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Requirement already satisfied: python-dotenv in /opt/conda/lib/python3.11/site-packages (from roboflow>=0.2.29->yolov5) (0.19.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from roboflow>=0.2.29->yolov5) (1.17.0)
# Collecting requests-toolbelt (from roboflow>=0.2.29->yolov5)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow>=0.2.29->yolov5)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from sahi>=0.11.10->yolov5) (8.1.8)
# Collecting opencv-python>=4.1.1 (from yolov5)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting pybboxes==0.1.6 (from sahi>=0.11.10->yolov5)
#   Downloading pybboxes-0.1.6-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: shapely>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from sahi>=0.11.10->yolov5) (2.0.6)
# Collecting terminaltables (from sahi>=0.11.10->yolov5)
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting absl-py>=0.4 (from tensorboard>=2.4.1->yolov5)
#   Downloading absl_py-2.2.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: grpcio>=1.48.2 in /opt/conda/lib/python3.11/site-packages (from tensorboard>=2.4.1->yolov5) (1.69.0)
# Collecting markdown>=2.6.8 (from tensorboard>=2.4.1->yolov5)
#   Downloading markdown-3.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/conda/lib/python3.11/site-packages (from tensorboard>=2.4.1->yolov5) (5.29.3)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.4.1->yolov5)
#   Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.4.1->yolov5)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.7.0->yolov5) (1.13.3)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch>=1.7.0->yolov5) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.7.0->yolov5) (3.1.5)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0.100->yolov5) (9.0.0)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics>=8.0.100->yolov5)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Collecting termcolor (from fire->yolov5)
#   Downloading termcolor-3.1.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->yolov5) (5.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.7.0->yolov5) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.4.1->yolov5) (3.0.2)
# Downloading yolov5-7.0.14-py37.py38.py39.py310-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.5/953.5 kB 26.8 MB/s eta 0:00:00
# Downloading boto3-1.38.19-py3-none-any.whl (139 kB)
# Downloading huggingface_hub-0.24.7-py3-none-any.whl (417 kB)
# Downloading roboflow-1.1.64-py3-none-any.whl (85 kB)
# Downloading idna-3.7-py3-none-any.whl (66 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 60.5 MB/s eta 0:00:00:00:0100:01
# Downloading sahi-0.11.23-py3-none-any.whl (114 kB)
# Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 59.5 MB/s eta 0:00:00:00:0100:01
# Downloading tensorboard-2.19.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 111.3 MB/s eta 0:00:00
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Downloading ultralytics-8.3.140-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 43.8 MB/s eta 0:00:00
# Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
# Downloading botocore-1.38.19-py3-none-any.whl (13.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 147.7 MB/s eta 0:00:00
# Downloading markdown-3.8-py3-none-any.whl (106 kB)
# Downloading pillow_heif-0.22.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.1 MB/s eta 0:00:00
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 74.6 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.7.0-py3-none-any.whl size=114249 sha256=9b5d04e37c181d0899cee36eb162dbed6908b76ebb451215bbd15026d632e3cd
#   Stored in directory: /home/jovyan/.cache/pip/wheels/46/54/24/1624fd5b8674eb1188623f7e8e17cdf7c0f6c24b609dfb8a89
# Successfully built fire
# Installing collected packages: filetype, werkzeug, terminaltables, termcolor, tensorboard-data-server, pybboxes, pillow-heif, opencv-python-headless, opencv-python, markdown, idna, absl-py, tensorboard, fire, botocore, ultralytics-thop, thop, sahi, s3transfer, requests-toolbelt, huggingface-hub, ultralytics, roboflow, boto3, yolov5
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.11.0.86
#     Uninstalling opencv-python-4.11.0.86:
#       Successfully uninstalled opencv-python-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.35.93
#     Uninstalling botocore-1.35.93:
#       Successfully uninstalled botocore-1.35.93
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.17.0 requires botocore<1.35.94,>=1.35.74, but you have botocore 1.38.19 which is incompatible.
# jupyterlab-git 0.50.1 requires jupyter-server<3,>=2.0.1, but you have jupyter-server 1.24.0 which is incompatible.
# jupyterhub 5.2.1 requires pydantic>=2, but you have pydantic 1.10.20 which is incompatible.
# Successfully installed absl-py-2.2.2 boto3-1.38.19 botocore-1.38.19 filetype-1.2.0 fire-0.7.0 huggingface-hub-0.24.7 idna-3.7 markdown-3.8 opencv-python-4.10.0.84 opencv-python-headless-4.10.0.84 pillow-heif-0.22.0 pybboxes-0.1.6 requests-toolbelt-1.0.0 roboflow-1.1.64 s3transfer-0.12.0 sahi-0.11.23 tensorboard-2.19.0 tensorboard-data-server-0.7.2 termcolor-3.1.0 terminaltables-3.1.10 thop-0.1.1.post2209072238 ultralytics-8.3.140 ultralytics-thop-2.0.14 werkzeug-3.1.3 yolov5-7.0.14

# %%
import cv2
import torch
from matplotlib import pyplot as plt

# %%
# Load YOLOv5s model (small, fast)
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# Load your drone video frame or footage
video_path = 'your_drone_video.mp4'
cap = cv2.VideoCapture(video_path)

# Process first frame only (for demo)
ret, frame = cap.read()
if not ret:
    print("Failed to load video")
    exit()

# Convert to RGB
img = frame[:, :, ::-1]

# Run inference
results = model(img)

# Render results
results.render()

# Show detections
plt.figure(figsize=(12, 8))
plt.imshow(results.imgs[0])
plt.axis('off')
plt.title("YOLOv5 Detections on Drone Frame")
plt.show()

# Print detected object summary
print("Detected object classes:\n", results.pandas().xyxy[0]['name'].value_counts())

cap.release()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load YOLOv5s model (small, fast)
# ----> 2 model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
#       4 # Load your drone video frame or footage
#       5 video_path = 'your_drone_video.mp4'
#
# NameError: name 'torch' is not defined
